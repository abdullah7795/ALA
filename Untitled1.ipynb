# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.style.use('seaborn-whitegrid')
# %matplotlib inline

# %%
x = (1e5*stats.norm.pdf(np.arange(0, 100), 40, 20)).astype(int)
fig, ax1 = plt.subplots(1, 1, figsize = (6, 6))
fig.tight_layout(pad = 4.0)
ax1.bar(np.arange(0, 100), x,)
ax1.set_xlabel('Age')
ax1.set_ylabel('Count')
ax1.set_title('Age distribution across 0-99 years old')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e2f24a7f6e87> in <module>
# ----> 1 x = (1e5*stats.norm.pdf(np.arange(0, 100), 40, 20)).astype(int)
#       2 fig, ax1 = plt.subplots(1, 1, figsize = (6, 6))
#       3 fig.tight_layout(pad = 4.0)
#       4 ax1.bar(np.arange(0, 100), x,)
#       5 ax1.set_xlabel('Age')
#
# NameError: name 'stats' is not defined

# %%
import numpy as np
a=np.array([[76,126,38],[74,120,38],[72,118,37.5],[78,136,37]])
v=np.array([[1,0,0],[0,1,0],[1,1,1],[-1,-1,-1]])

for i in range(0,4):
  for j in range (0,4):
    print(str(np.dot(a[i],v[j])/np.linalg.norm(v[j]))+'              when patient is '+ str(i+1)+ 'and v is '+str(j+1))
# Out:
# 76.0              when patient is 1and v is 1
# 126.0              when patient is 1and v is 2
# 138.5640646055102              when patient is 1and v is 3
# -138.5640646055102              when patient is 1and v is 4
# 74.0              when patient is 2and v is 1
# 120.0              when patient is 2and v is 2
# 133.9452624519932              when patient is 2and v is 3
# -133.9452624519932              when patient is 2and v is 4
# 72.0              when patient is 3and v is 1
# 118.0              when patient is 3and v is 2
# 131.34718624063987              when patient is 3and v is 3
# -131.34718624063987              when patient is 3and v is 4
# 78.0              when patient is 4and v is 1
# 136.0              when patient is 4and v is 2
# 144.91491756659607              when patient is 4and v is 3
# -144.91491756659607              when patient is 4and v is 4

# %%
for i in range (0,4):
  print(np.dot(a,v[i])/np.linalg.norm(v[i]))
# Out:
# [76. 74. 72. 78.]
# [126. 120. 118. 136.]
# [138.56406461 133.94526245 131.34718624 144.91491757]
# [-138.56406461 -133.94526245 -131.34718624 -144.91491757]

# %%
np.dot(a,v)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-b77dcbba75cd> in <module>
# ----> 1 np.dot(a,v)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (4,3) and (4,3) not aligned: 3 (dim 1) != 4 (dim 0)

# %%
import numpy.matlib 
import numpy as np 

a = np.array([[1,2,1],[3,4,1]]) 
b = np.array([[11,12,1],[13,14,1],[3,4,1]]) 
np.dot(a,b)
# Out:
# array([[40, 44,  4],
#        [88, 96,  8]])

# %%
a=np.array([[76,126,38],[74,120,38],[72,118,37.5],[78,136,37]])
v=np.array([[1,0,0],[0,1,0],[1,1,1],[-1,-1,-1]])
